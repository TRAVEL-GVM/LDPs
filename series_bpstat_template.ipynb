# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import obiwan as obi
import datetime

# %% [markdown]
# # BPSERIES KEYS SERIES

# %% [markdown]
# https://bpstat.bportugal.pt/pesquisa/?searchTerm=free%20cash%20flow%20g%C3%A1s&tab=series&code=VET&page=1&page_size=50&fixedTab=1

# %% [markdown]
# https://bpstat.bportugal.pt/serie/12599533
#
# - Transp aéreos
# - Comérc automóvel
# - Fabric automóvel
# - Construção
# - Farmacêutico-Ind farmacêutica-%
# - Tecn informação
# - Madeira e papel-%
# - Aloj e restauração-Restauração-%
# - Setor do mar-Transp marítimo-%
# - Ind alimentares-%
# - Info e comunicação-Telecomunic-%
# - Calçado
# - Transportes
# - Comércio
# - Água e resíduos
# - Grosso
# - Retalho
# - Gás
# - Text
# - Restauração

# %%
indicadores = {
    
    "Liquidez geral": [12656203, 12690835, 12693946, 12657849, 12672260, 12649394, 12696767, 12697453, 12693833, 12663106,
                      12599318, 12679656, 12664610, 12693105, 12646374, 12735076, 12735076],
    "Autonomia Financeira": [12635300, 12632936, 12648166, 12639218, 12813569, 12674801, 12635761, 12637936, 12666520,
                            12670032, 12682698, 12697703, 12681911, 12732718, 12658172, 12670032, 12635372, 12679539],
    "Financiamentos obtidos (% do passivo)": [12623362, 12608571, 12595207, 12618120, 12721495, 12603749, 12715386],
    "Custo dos financiamentos obtidos": [12666991, 12683953, 12648948, 12692345, 12647100, 12673043, 12656030, 12661701,
                                        12665365, 12660176, 12680707, 12665700, 12733795],
    "Rendibilidade do ativo": [12693376, 12664602, 12732717, 12672706, 12664627, 12646614, 12637937, 12661426, 12635770,
                              12659704, 12639219, 12695818, 12694257, 12651038, 12632937, 12635301,  12687839, 12635373, 
                              12684683, 12664627],
    "Rendibilidade bruta dos capitais investidos": [12719770, 12598218, 12626560, 12595740, 12587440, 12621254, 12720020],
    "Cobertura dos gastos de financiamento": [12655571, 12663003, 12660341, 12661698, 12668002, 12672741, 12675876, 12679513, 12679972,
                                             12695785, 12735072, 12656506, 12669219, 12649291, 12664021, 12659490, 12695206],
    "Financiamentos obtidos em % ativo": [12655617, 12687142, 12695079, 12733796,  12696505, 12673132, 12664773, 12664600, 12657555,
                                         12649992, 12794416, 12656219, 12693139, 12693693, 12683552],
    "Margem EBITDA em % dos rendimentos": [12635663, 12638892, 12635374, 12636858, 12637572, 12634175, 12635302, 12632938,
                                          12633338, 12724101, 12591794, 12639220, 12637536,  12637938, 12633428, 12633255,
                                          12618427, 12635771],
    "Rácio dos financiamentos obtidos sobre EBITDA": [12725322, 12609203, 12630347, 12594217, 12594493, 12613764, 12713960, 12628663],
    "Rendibilidade dos capitais próprios": [12666653, 12670585, 12635377, 12659421, 12635305, 12632941, 12686588, 12679007, 12694401, 12657331,
                                           12733799, 12651582, 12690659, 12639223, 12673201, 12635774, 12637941, 12682868, 12671634],
    "Margem líquida em % dos rendimentos": [12638896, 12635378, 12635667, 12633547, 12635306, 12632942, 12633342, 12632522,
                                           12639224, 12637540, 12635775, 12637942, 12613393, 12635198, 12596294, 12724588],
    "Free cash flow": [12729956, 12587359, 12587536, 12588555, 12590492, 12590767, 12594581],
    "Caixa e depósitos bancários em % do ativo": [12619844, 12589953, 12621615, 12612082, 12621615, 12589953],
    "Margem bruta em % dos rendimentos": [12615278, 12605684, 12598345, 12712860, 12622978],
    "Gastos de depreciação e de amortização": [12598588, 12616413, 12627440, 12598457, 12590944, 12721424],
    "Depreciação (% rendimentos)": [12628936, 12627801, 12612370, 12616893, 12719235],
    "EBITDA em % do volume de negócios": [12715658, 12593289, 12714136, 12589370, 12713010, 12598383],
    "Pressão financeira (gastos de financiamento)": [12635670, 12638899, 12712861, 12633550, 12635417, 12632945, 12635309, 12633345, 12635742, 12635381,
                                                     12639227, 12637543, 12635778, 12637945, 12632776, 12627526, 12599533, 12635634, 12730579]
    
}

# %% [markdown]
# # EXTRAIR DADOS E GERAR EXCEL SEM HEADER

# %%
ano_atual = datetime.datetime.now().year - 1

df_final = pd.DataFrame()
df_final['Date'] = pd.date_range(start='2006-12-31', end=f'{ano_atual}-12-31', freq='A-DEC')

for setor, series_ids in indicadores.items():
    df_setor = pd.DataFrame()  
    for series_id in series_ids:
        df_extracted = obi.extract_data_from_bank_pt(series_id, None)
        
        df_final = df_final.merge(df_extracted, on='Date', how='left')
    
#df_final    

df_final.to_excel("indicadores_bpstat_sem_header.xlsx", index=False)

print("Ficheiro Excel criado com sucesso.")
# Out:
# Ficheiro Excel criado com sucesso.

# %% [markdown]
# # EXTRAIR DADOS E GERAR EXCEL COM HEADER FROM BPSTAT

# %%
ano_atual = datetime.datetime.now().year - 1

df_final_semh = pd.DataFrame()
df_final_semh['Date'] = pd.date_range(start='2006-12-31', end=f'{ano_atual}-12-31', freq='A-DEC')

colunas_nivel_1 = ['Date']  
colunas_nivel_2 = [''] 

for setor, series_ids in indicadores.items():
    df_setor = pd.DataFrame()  
    for series_id in series_ids:
        df_extracted = obi.extract_data_from_bank_pt(series_id, None)

        df_final_semh = df_final_semh.merge(df_extracted, on='Date', how='left')
        
        colunas_nivel_1.extend([setor] * (df_extracted.shape[1] - 1)) 
        colunas_nivel_2.extend(df_extracted.columns[1:]) 
        
df_final_semh.columns = pd.MultiIndex.from_tuples(list(zip(colunas_nivel_1, colunas_nivel_2)))
df_final_semh = df_final_semh.loc[:, ~df_final_semh.columns.duplicated()]

df_final_semh = df_final_semh.set_index('Date')

df_final_semh.columns = pd.MultiIndex.from_tuples(
    [(col[0], col[1].split('-')[1]) for col in df_final_semh.columns]
)

df_final_semh.index = df_final_semh.index.date

df_final_semh.head()
# Out:
#            Liquidez geral                                   \
#              C18 Printing J58 Publishing H51 Air transport
# 2006-12-31         109.00         130.65            171.56
# 2007-12-31         112.31         131.24            127.79
# 2008-12-31         111.10         124.05            125.44
# 2009-12-31         112.33         127.11            118.17
# 2010-12-31         127.30         122.00            151.35
#
#                                                                             \
#            G45 Trade motor vehicles F Construction C20 Chemicals C17 Paper
# 2006-12-31                   114.21         154.95        130.67    179.64
# 2007-12-31                   116.26         157.48        131.69    169.40
# 2008-12-31                   110.88         155.37        121.80    109.99
# 2009-12-31                   110.58         154.37        113.76    103.88
# 2010-12-31                   115.62         143.78        123.69    116.35
#
#                                                                                \
#            I56 Food service activities J63 Computer services G47 Retail trade
# 2006-12-31                       71.24                138.54           100.27
# 2007-12-31                       71.26                138.03            96.63
# 2008-12-31                       68.58                153.76            96.86
# 2009-12-31                       69.29                147.12            97.54
# 2010-12-31                       74.92                144.28           100.03
#
#             ... Pressão financeira (gastos de financiamento)           \
#             ...                                   Automobile Maritime
# 2006-12-31  ...                                         8.49     8.46
# 2007-12-31  ...                                         8.40     9.60
# 2008-12-31  ...                                        12.78    12.92
# 2009-12-31  ...                                        14.74     7.69
# 2010-12-31  ...                                        10.63    10.31
#
#                                                                                \
#            Food manufact Info & communication Footwear Transportation G Trade
# 2006-12-31         14.03                 6.61    19.74          26.74   20.17
# 2007-12-31         18.42                 7.15    17.05          26.25   20.47
# 2008-12-31         23.11                 8.71    19.27          39.93   26.48
# 2009-12-31         15.62                 7.24    16.54          29.68   22.08
# 2010-12-31         17.34                 2.35    18.41          22.03   22.01
#
#
#            E Water and waste Transportation electricity, gas and water
# 2006-12-31             15.80           6.67                      15.97
# 2007-12-31             18.42           8.41                      25.29
# 2008-12-31             21.95          15.00                      29.61
# 2009-12-31             18.53          12.32                      25.36
# 2010-12-31             18.60          23.16                      23.89
#
# [5 rows x 224 columns]

# %%
df_final_semh.to_excel("indicadores_bpstat_com_header.xlsx", index=True)

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Alignment
from openpyxl.utils import get_column_letter
from openpyxl import Workbook

wb = load_workbook("indicadores_bpstat_com_header.xlsx")
ws1 = wb.active
ws1.title = "BPSTAT_LDPs"

yellow_fill = PatternFill(start_color="FFFF00", end_color="FFFF00", fill_type="solid")
white_font = Font(color="FFFFFF", bold=True)
green_fill = PatternFill(start_color=obi.nb_default_color1.split('#')[1], end_color=obi.nb_default_color1.split('#')[1], fill_type="solid")
pink_fill = PatternFill(start_color="FFCCE5", end_color="FFCCE5", fill_type="solid")
blue_fill = PatternFill(start_color="311CEE", end_color="311CEE", fill_type="solid")


sheet = wb["BPSTAT_LDPs"]
sheet['A3'].fill = green_fill

for row in sheet.iter_rows(min_row=4, max_row=sheet.max_row, min_col=1, max_col=1):
    for cell in row:
        if isinstance(cell.value, pd.Timestamp):
            cell.value = cell.value.date()
        cell.fill = yellow_fill
        cell.font = Font(color="000000", bold=True) 
        cell.alignment = Alignment(horizontal="center", vertical="center")

for col in range(2, sheet.max_column + 1):
    for row in range(1, 3):
        cell = sheet.cell(row=row, column=col)
        if row == 1:
            cell.fill = pink_fill
            cell.font = Font(color="000000", bold=True)  
        elif row == 2:
            cell.fill = green_fill
            cell.font = Font(color="FFFFFF", bold=True) 
        cell.alignment = Alignment(horizontal="center", vertical="center")

for col in sheet.iter_cols(min_col=1, max_col=sheet.max_column):
    max_length = 0
    for cell in col:
        if cell.value:
            max_length = max(max_length, len(str(cell.value)))
    sheet.column_dimensions[get_column_letter(col[0].column)].width = max_length + 2

sheet['A3'] = 'Date'
sheet['A3'].alignment = Alignment(horizontal="center", vertical="center")
sheet['A3'].font = Font(bold=True)


wb.save("output_bpstat.xlsx")

# %% [markdown]
# # EXTRAÇÃO DE DADOS DO ECB E GERAR FICHEIRO TAMBÉM DADOS BPSTAT
#
# https://data.ecb.europa.eu/main-figures/macroeconomic-and-sectoral-indicators
#
# https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.A.F.F._Z._Z.XDC._T.S.V.F4._T

# %%
indicadores_ecb = {
    
    "GDP and expenditure components": {
        "Private final consumption, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W0.S1M.S1.D.P31._Z._Z._T.XDC.LR.GY",
        "Private final consumption, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W0.S1M.S1.D.P31._Z._Z._T.XDC.LR.GY",
        "Gross fixed capital formation, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W0.S1.S1.D.P51G.N11G._T._Z.XDC.LR.GY",
        "Gross fixed capital formation, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W0.S1.S1.D.P51G.N11G._T._Z.XDC.LR.GY",
        "Government final consumption, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W0.S13.S1.D.P3._Z._Z._T.XDC.LR.GY",
        "Government final consumption, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W0.S13.S1.D.P3._Z._Z._T.XDC.LR.GY",
        "Imports of goods and services, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W1.S1.S1.C.P7._Z._Z._Z.XDC.LR.GY", 
        "Imports of goods and services, Portugal, Annual" :"https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W1.S1.S1.C.P7._Z._Z._Z.XDC.LR.GY",
        "Exports of goods and services, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W1.S1.S1.D.P6._Z._Z._Z.XDC.LR.GY",
        "Exports of goods and services, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W1.S1.S1.D.P6._Z._Z._Z.XDC.LR.GY",
        "Gross domestic product at market prices, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC.LR.GY",
        "Gross domestic product at market prices, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC_R_B1GQ.Y.GOY",
        },

    "Corporations": {
        "Net value added of Non financial corporations (growth rate), Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1._Z.B.B1N._Z._Z._Z.XDC._T.S.V.G4._T",
        "Net value added of Non financial corporations (growth rate), Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1._Z.B.B1N._Z._Z._Z.XDC._T.S.V.GY._T",
        "Gross entrepreneurial income of Non financial corporations as a ratio of gross value added, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1._Z.B.B4G._Z._Z._Z.XDC_R_B1G_CY._T.S.V.C4._T",
        "Gross entrepreneurial income of Non financial corporations, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1._Z.B.B4G._Z._Z._Z.XDC_R_B1G._T.S.V.N._T",
        "Debt securities and loans of Non financial corporations as a ratio of GDP, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.C.L.LE.F3T4.T._Z.XDC_R_B1GQ_CY._T.S.V.N._T",
        "Debt securities and loans of Non financial corporations as a ratio of GDP, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.C.L.LE.F3T4.T._Z.XDC_R_B1GQ_CY._T.S.V.N._T",
        "Debt of Non financial corporations as a ratio of total financial liabilities, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.L.LE.FPT.T._Z.XDC_R_F._T.S.V.N._T",
        "Debt of Non financial corporations as a ratio of total financial liabilities, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.L.LE.FPT.T._Z.XDC_R_F._T.S.V.N._T",
        "Total financial assets of Non financial corporations (growth rate), Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.A.F.F._Z._Z.XDC._T.S.V.F4._T",
        "Total financial assets of Non financial corporations as a ratio of total financial assets, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.A.F.F._Z._Z.XDC._T.S.V.FY._T",
        "Total financial liabilities of Non financial corporations (growth rate), Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.L.F.F._Z._Z.XDC._T.S.V.F4._T",
        "Total financial liabilities of Non financial corporations as a ratio of total financial assets, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.L.F.F._Z._Z.XDC._T.S.V.FY._T",
        "Gross fixed capital formation of Non financial corporations as a ratio of gross value added, Portugal, Quarterly": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.D.P51G._Z._Z._Z.XDC_R_B1G_CY._T.S.V.C4._T",
        "Gross fixed capital formation of Non financial corporations as a ratio of gross value added, Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.D.P51G._Z._Z._Z.XDC_R_B1G_CY._T.S.V.N._T"
        },

    "Households": {
        "Loans granted to households as a ratio of gross disposable income, Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.L.LE.F4.T._Z.XDC_R_B6G_CY._T.S.V.N._T",
        "Loans granted to households as a ratio of gross disposable income, Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.L.LE.F4.T._Z.XDC_R_B6G_CY._T.S.V.N._T",
        "Gross saving of households as a ratio of adjusted gross disposable income, Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1._Z.B.B8G._Z._Z._Z.XDC_R_B6GA_CY._T.S.V.C4._T",
        "Gross saving of households as a ratio of adjusted gross disposable income, Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1._Z.B.B8G._Z._Z._Z.XDC_R_B6GA_CY._T.S.V.N._T",
        "Gross disposable income of households (growth rate), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1._Z.B.B6G._Z._Z._Z.XDC._T.S.V.G4._T",
        "Gross disposable income of households (growth rate), Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1._Z.B.B6G._Z._Z._Z.XDC._T.S.V.GY._T",
        "Total financial assets of households (growth rate), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.A.F.F._Z._Z.XDC._T.S.V.F4._T",
        "Total financial assets of households as a ratio of total financial assets, Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.A.F.F._Z._Z.XDC._T.S.V.FY._T",
        "Loans granted to households (growth rate), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.L.F.F4.T._Z.XDC._T.S.V.F4._T",
        "Loans granted to households as a ratio of total financial assets, Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.L.F.F4.T._Z.XDC._T.S.V.FY._T",
        "Gross fixed capital formation of households as a ratio of adjusted gross disposable income, Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.D.P51G._Z._Z._Z.XDC_R_B6GA_CY._T.S.V.C4._T",
        "Gross fixed capital formation of households as a ratio of adjusted gross disposable income, Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.D.P51G._Z._Z._Z.XDC_R_B6GA_CY._T.S.V.N._T",
        "Loans granted to households as a ratio of gross disposable income, Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.L.LE.F4.T._Z.XDC_R_B6G_CY._T.S.V.N._T",
        "Final consumption expenditure of households (growth rate), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.D.P3._Z._Z._Z.XDC._T.S.V.G4._T",
        "Final consumption expenditure of households (growth rate), Portugal, Annual": "https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.D.P3._Z._Z._Z.XDC._T.S.V.GY._T"
        },

    "Government finance statistics": {
        "Government deficit(-) or surplus(+) (as % of GDP), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/GFS/GFS.Q.N.PT.W0.S13.S1._Z.B.B9._Z._Z._Z.XDC_R_B1GQ_CY._Z.S.V.CY._T",
        "Government deficit(-) or surplus(+) (as % of GDP), Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/GFS/GFS.A.N.PT.W0.S13.S1._Z.B.B9._Z._Z._Z.XDC_R_B1GQ._Z.S.V.N._T",
        "Government primary deficit(-) or surplus(+) (as % of GDP), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/GFS/GFS.Q.N.PT.W0.S13.S1._Z.B.B9P._Z._Z._Z.XDC_R_B1GQ_CY._Z.S.V.CY._T",
        "Government primary deficit(-) or surplus(+) (as % of GDP), Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/GFS/GFS.A.N.PT.W0.S13.S1._Z.B.B9P._Z._Z._Z.XDC_R_B1GQ._Z.S.V.N._T",
        "Government debt (consolidated) (as % of GDP), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/GFS/GFS.Q.N.PT.W0.S13.S1.C.L.LE.GD.T._Z.XDC_R_B1GQ_CY._T.F.V.N._T",
        "Government debt (consolidated) (as % of GDP), Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/GFS/GFS.A.N.PT.W0.S13.S1.C.L.LE.GD.T._Z.XDC_R_B1GQ._T.F.V.N._T"
        },

    "Labour market indicators": {
        "Total employment, Euro area 20 (fixed composition) as of 1 January 2023, Quarterly" : "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.N.I9.W2.S1.S1._Z.EMP._Z._T._Z.PS._Z.GY",
        "Unemployment rate, Portugal, Monthly" : "https://data.ecb.europa.eu/data/datasets/LFSI/LFSI.M.PT.S.UNEHRT.TOTAL0.15_74.T",
        "Labour Productivity (per persons), Portugal, Quarterly" : "https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.S.PT.W0.S1.S1._Z.LPR_PS._Z._T._Z.XDC.LR.GY",
        "Gross fixed capital formation, Portugal, Annual" : "https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W0.S1.S1.D.P51G.N11G._T._Z.XDC.LR.GY",
        }
    
}

# %%
def transform_data(d):
    new_data = {}
    for key, value in d.items():
        new_data[key] = {}
        for sub_key, url in value.items():
            if "Quarterly" in sub_key:
                periodicity = "Quarterly"
                new_key = sub_key.replace(", Quarterly", "")
            elif "Monthly" in sub_key:
                periodicity = "Monthly"
                new_key = sub_key.replace(", Monthly", "")
            elif "Annual" in sub_key:
                periodicity = "Annual"
                new_key = sub_key.replace(", Annual", "")
            else:
                periodicity = "Unknown"
                new_key = sub_key
            
            new_data[key][new_key] = {
                "periodicity": periodicity,
                "url": url
            }
    
    return new_data

transformed_data = transform_data(indicadores_ecb)

# %%
transformed_data
# Out:
# {'GDP and expenditure components': {'Private final consumption, Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W0.S1M.S1.D.P31._Z._Z._T.XDC.LR.GY'},
#   'Gross fixed capital formation, Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.Y.PT.W0.S1.S1.D.P51G.N11G._T._Z.XDC.LR.GY'},
#   'Government final consumption, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W0.S13.S1.D.P3._Z._Z._T.XDC.LR.GY'},
#   'Imports of goods and services, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W1.S1.S1.C.P7._Z._Z._Z.XDC.LR.GY'},
#   'Exports of goods and services, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W1.S1.S1.D.P6._Z._Z._Z.XDC.LR.GY'},
#   'Gross domestic product at market prices, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC_R_B1GQ.Y.GOY'}},
#  'Corporations': {'Net value added of Non financial corporations (growth rate), Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1._Z.B.B1N._Z._Z._Z.XDC._T.S.V.GY._T'},
#   'Gross entrepreneurial income of Non financial corporations as a ratio of gross value added, Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1._Z.B.B4G._Z._Z._Z.XDC_R_B1G_CY._T.S.V.C4._T'},
#   'Gross entrepreneurial income of Non financial corporations, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1._Z.B.B4G._Z._Z._Z.XDC_R_B1G._T.S.V.N._T'},
#   'Debt securities and loans of Non financial corporations as a ratio of GDP, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.C.L.LE.F3T4.T._Z.XDC_R_B1GQ_CY._T.S.V.N._T'},
#   'Debt of Non financial corporations as a ratio of total financial liabilities, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.L.LE.FPT.T._Z.XDC_R_F._T.S.V.N._T'},
#   'Total financial assets of Non financial corporations (growth rate), Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.A.F.F._Z._Z.XDC._T.S.V.F4._T'},
#   'Total financial assets of Non financial corporations as a ratio of total financial assets, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.A.F.F._Z._Z.XDC._T.S.V.FY._T'},
#   'Total financial liabilities of Non financial corporations (growth rate), Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S11.S1.N.L.F.F._Z._Z.XDC._T.S.V.F4._T'},
#   'Total financial liabilities of Non financial corporations as a ratio of total financial assets, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.L.F.F._Z._Z.XDC._T.S.V.FY._T'},
#   'Gross fixed capital formation of Non financial corporations as a ratio of gross value added, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S11.S1.N.D.P51G._Z._Z._Z.XDC_R_B1G_CY._T.S.V.N._T'}},
#  'Households': {'Loans granted to households as a ratio of gross disposable income, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.L.LE.F4.T._Z.XDC_R_B6G_CY._T.S.V.N._T'},
#   'Gross saving of households as a ratio of adjusted gross disposable income, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1._Z.B.B8G._Z._Z._Z.XDC_R_B6GA_CY._T.S.V.N._T'},
#   'Gross disposable income of households (growth rate), Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1._Z.B.B6G._Z._Z._Z.XDC._T.S.V.GY._T'},
#   'Total financial assets of households (growth rate), Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.A.F.F._Z._Z.XDC._T.S.V.F4._T'},
#   'Total financial assets of households as a ratio of total financial assets, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.A.F.F._Z._Z.XDC._T.S.V.FY._T'},
#   'Loans granted to households (growth rate), Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.Q.N.PT.W0.S1M.S1.N.L.F.F4.T._Z.XDC._T.S.V.F4._T'},
#   'Loans granted to households as a ratio of total financial assets, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.L.F.F4.T._Z.XDC._T.S.V.FY._T'},
#   'Gross fixed capital formation of households as a ratio of adjusted gross disposable income, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.D.P51G._Z._Z._Z.XDC_R_B6GA_CY._T.S.V.N._T'},
#   'Final consumption expenditure of households (growth rate), Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/QSA/QSA.A.N.PT.W0.S1M.S1.N.D.P3._Z._Z._Z.XDC._T.S.V.GY._T'}},
#  'Government finance statistics': {'Government deficit(-) or surplus(+) (as % of GDP), Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/GFS/GFS.A.N.PT.W0.S13.S1._Z.B.B9._Z._Z._Z.XDC_R_B1GQ._Z.S.V.N._T'},
#   'Government primary deficit(-) or surplus(+) (as % of GDP), Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/GFS/GFS.A.N.PT.W0.S13.S1._Z.B.B9P._Z._Z._Z.XDC_R_B1GQ._Z.S.V.N._T'},
#   'Government debt (consolidated) (as % of GDP), Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/GFS/GFS.A.N.PT.W0.S13.S1.C.L.LE.GD.T._Z.XDC_R_B1GQ._T.F.V.N._T'}},
#  'Labour market indicators': {'Total employment, Euro area 20 (fixed composition) as of 1 January 2023': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.N.I9.W2.S1.S1._Z.EMP._Z._T._Z.PS._Z.GY'},
#   'Unemployment rate, Portugal': {'periodicity': 'Monthly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/LFSI/LFSI.M.PT.S.UNEHRT.TOTAL0.15_74.T'},
#   'Labour Productivity (per persons), Portugal': {'periodicity': 'Quarterly',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.Q.S.PT.W0.S1.S1._Z.LPR_PS._Z._T._Z.XDC.LR.GY'},
#   'Gross fixed capital formation, Portugal': {'periodicity': 'Annual',
#    'url': 'https://data.ecb.europa.eu/data/datasets/MNA/MNA.A.N.PT.W0.S1.S1.D.P51G.N11G._T._Z.XDC.LR.GY'}}}

# %%
def extract_and_combine_data(transformed_data, periodicity, start_date='2020-01'):
    combined_series = pd.DataFrame()

    for category, indicators in transformed_data.items():
        for indicator, details in indicators.items():
            if details['periodicity'] == periodicity:
                url = details['url'].split("datasets/")[1].split('/')[1]
                data = obi.extract_data_from_ecb(url, start_date)
                if not data.empty:
                    data.rename(columns={'OBS_VALUE': indicator}, inplace=True)
                    if combined_series.empty:
                        combined_series = data
                    else:
                        combined_series = pd.merge(combined_series, data, on='TIME_PERIOD', how='outer')

    return combined_series

# %%
quarterly_ecb_data = extract_and_combine_data(transformed_data, 'Quarterly')
quarterly_ecb_data['TIME_PERIOD'] = quarterly_ecb_data['TIME_PERIOD'].dt.date
quarterly_ecb_data
# Out:
#    TIME_PERIOD  Private final consumption, Portugal  \
# 0   2020-01-01                            -1.008016
# 1   2020-04-01                           -16.552394
# 2   2020-07-01                            -4.256041
# 3   2020-10-01                            -5.242758
# 4   2021-01-01                            -7.222002
# 5   2021-04-01                            18.309277
# 6   2021-07-01                             4.495336
# 7   2021-10-01                             6.114251
# 8   2022-01-01                            12.563028
# 9   2022-04-01                             3.990326
# 10  2022-07-01                             3.381712
# 11  2022-10-01                             2.985907
# 12  2023-01-01                             2.193481
# 13  2023-04-01                             2.759318
# 14  2023-07-01                             0.843791
# 15  2023-10-01                             1.842830
# 16  2024-01-01                             1.516354
# 17  2024-04-01                             2.420643
# 18  2024-07-01                             3.812462
# 19  2024-10-01                             5.024158
#
#     Gross fixed capital formation, Portugal  \
# 0                                 -1.259336
# 1                                 -8.579667
# 2                                 -0.101212
# 3                                  0.570004
# 4                                  3.803724
# 5                                 14.359627
# 6                                  5.372246
# 7                                  8.151466
# 8                                  7.101107
# 9                                  2.763935
# 10                                 3.071704
# 11                                 0.573286
# 12                                 1.269410
# 13                                 3.732830
# 14                                 4.161254
# 15                                 5.211635
# 16                                 1.069626
# 17                                 3.051222
# 18                                 4.391085
# 19                                 0.737433
#
#     Gross entrepreneurial income of Non financial corporations as a ratio of gross value added, Portugal  \
# 0                                           41.658218
# 1                                           40.736724
# 2                                           40.767762
# 3                                           40.073375
# 4                                           40.641991
# 5                                           42.199310
# 6                                           41.880407
# 7                                           42.351140
# 8                                           41.900753
# 9                                           41.629221
# 10                                          41.880882
# 11                                          42.801191
# 12                                          42.485733
# 13                                          42.759418
# 14                                          42.208162
# 15                                          41.402639
# 16                                          40.877570
# 17                                          39.886785
# 18                                          39.879762
# 19                                                NaN
#
#     Total financial assets of Non financial corporations (growth rate), Portugal  \
# 0                                            0.784481
# 1                                            1.864120
# 2                                            2.945065
# 3                                            3.916514
# 4                                            5.793014
# 5                                            5.273468
# 6                                            4.191833
# 7                                            3.778129
# 8                                            2.653388
# 9                                            2.273781
# 10                                           1.981368
# 11                                           2.451700
# 12                                           2.158640
# 13                                           0.453326
# 14                                           0.819160
# 15                                          -1.509845
# 16                                          -1.433663
# 17                                          -0.531506
# 18                                          -2.052114
# 19                                                NaN
#
#     Total financial liabilities of Non financial corporations (growth rate), Portugal  \
# 0                                            1.378025
# 1                                            2.037655
# 2                                            2.310132
# 3                                            2.775165
# 4                                            3.842996
# 5                                            3.349567
# 6                                            3.132625
# 7                                            3.037919
# 8                                            2.449718
# 9                                            2.753584
# 10                                           2.810038
# 11                                           2.833120
# 12                                           2.582455
# 13                                           1.313076
# 14                                           1.658741
# 15                                           0.343787
# 16                                           0.252845
# 17                                           0.978236
# 18                                           0.035598
# 19                                                NaN
#
#     Total financial assets of households (growth rate), Portugal  \
# 0                                            1.363584
# 1                                            2.464528
# 2                                            2.699639
# 3                                            2.953375
# 4                                            3.749417
# 5                                            3.116117
# 6                                            3.213841
# 7                                            2.888199
# 8                                            2.142845
# 9                                            2.251872
# 10                                           1.636354
# 11                                           1.733002
# 12                                           0.977248
# 13                                           0.731068
# 14                                           0.799094
# 15                                           0.705166
# 16                                           1.700011
# 17                                           2.056573
# 18                                           2.957960
# 19                                                NaN
#
#     Loans granted to households (growth rate), Portugal  \
# 0                                            1.269223
# 1                                            1.091716
# 2                                            1.518988
# 3                                            1.727187
# 4                                            2.179259
# 5                                            3.216079
# 6                                            3.521974
# 7                                            3.740656
# 8                                            4.160184
# 9                                            4.164902
# 10                                           3.959274
# 11                                           3.249446
# 12                                           1.955913
# 13                                           0.885232
# 14                                           0.281019
# 15                                           0.126336
# 16                                           0.650597
# 17                                           1.537778
# 18                                           2.342830
# 19                                                NaN
#
#     Total employment, Euro area 20 (fixed composition) as of 1 January 2023  \
# 0                                            0.483336
# 1                                           -2.743320
# 2                                           -1.968714
# 3                                           -1.471045
# 4                                           -1.291782
# 5                                            2.387974
# 6                                            2.603994
# 7                                            2.543105
# 8                                            3.216455
# 9                                            2.838178
# 10                                           1.928241
# 11                                           1.685191
# 12                                           1.632046
# 13                                           1.401201
# 14                                           1.371905
# 15                                           1.316239
# 16                                           1.139917
# 17                                           0.942233
# 18                                           1.006338
# 19                                           0.737438
#
#     Labour Productivity (per persons), Portugal
# 0                                     -1.965161
# 1                                    -14.673158
# 2                                     -3.452963
# 3                                     -5.452797
# 4                                     -2.692835
# 5                                     13.082541
# 6                                      2.401253
# 7                                      4.761672
# 8                                      5.556047
# 9                                      4.113140
# 10                                     1.790513
# 11                                     1.361930
# 12                                     2.601022
# 13                                     1.702502
# 14                                     1.207097
# 15                                     0.703543
# 16                                    -0.219612
# 17                                     0.179550
# 18                                     0.066010
# 19                                     1.156070

# %%
annual_ecb_data = extract_and_combine_data(transformed_data, 'Annual')
annual_ecb_data['TIME_PERIOD'] = (annual_ecb_data['TIME_PERIOD']).astype(str).str[-4:].astype(int)
annual_ecb_data
# Out:
#    TIME_PERIOD  Government final consumption, Portugal  \
# 0         2020                                0.398942
# 1         2021                                3.784391
# 2         2022                                1.656845
# 3         2023                                0.593048
# 4         2024                                1.053851
#
#    Imports of goods and services, Portugal  \
# 0                               -11.590377
# 1                                12.258844
# 2                                11.265565
# 3                                 1.796337
# 4                                 4.769482
#
#    Exports of goods and services, Portugal  \
# 0                               -18.334661
# 1                                12.034544
# 2                                17.152864
# 3                                 3.803727
# 4                                 3.418246
#
#    Gross domestic product at market prices, Portugal  \
# 0                                          -8.204631
# 1                                           5.558758
# 2                                           6.985840
# 3                                           2.613129
# 4                                           1.899942
#
#    Net value added of Non financial corporations (growth rate), Portugal  \
# 0                                         -11.474540
# 1                                           8.613068
# 2                                          16.692040
# 3                                          11.296385
# 4                                                NaN
#
#    Gross entrepreneurial income of Non financial corporations, Portugal  \
# 0                                          40.073375
# 1                                          42.351140
# 2                                          42.801191
# 3                                          41.402639
# 4                                                NaN
#
#    Debt securities and loans of Non financial corporations as a ratio of GDP, Portugal  \
# 0                                          92.290655
# 1                                          87.851286
# 2                                          78.589222
# 3                                          70.783122
# 4                                                NaN
#
#    Debt of Non financial corporations as a ratio of total financial liabilities, Portugal  \
# 0                                          40.811918
# 1                                          40.423061
# 2                                          38.947091
# 3                                          36.839599
# 4                                                NaN
#
#    Total financial assets of Non financial corporations as a ratio of total financial assets, Portugal  \
# 0                                           3.916514
# 1                                           3.778129
# 2                                           2.451700
# 3                                          -1.509845
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Gross saving of households as a ratio of adjusted gross disposable income, Portugal  \
# 0                                          12.047856
# 1                                          10.952782
# 2                                           7.329643
# 3                                           7.989961
# 4                                                NaN
#
#    Gross disposable income of households (growth rate), Portugal  \
# 0                                          -0.852711
# 1                                           5.629849
# 2                                           8.890484
# 3                                           7.221603
# 4                                                NaN
#
#    Total financial assets of households as a ratio of total financial assets, Portugal  \
# 0                                           2.953375
# 1                                           2.888199
# 2                                           1.733002
# 3                                           0.705166
# 4                                                NaN
#
#    Loans granted to households as a ratio of total financial assets, Portugal  \
# 0                                           1.727187
# 1                                           3.740656
# 2                                           3.249446
# 3                                           0.126336
# 4                                                NaN
#
#    Gross fixed capital formation of households as a ratio of adjusted gross disposable income, Portugal  \
# 0                                           5.449846
# 1                                           5.843595
# 2                                           5.917920
# 3                                           5.793576
# 4                                                NaN
#
#    Final consumption expenditure of households (growth rate), Portugal  \
# 0                                          -6.355738
# 1                                           7.037437
# 2                                          13.247677
# 3                                           6.432624
# 4                                                NaN
#
#    Government deficit(-) or surplus(+) (as % of GDP), Portugal  \
# 0                                             -5.752
# 1                                             -2.825
# 2                                             -0.310
# 3                                              1.214
# 4                                                NaN
#
#    Government primary deficit(-) or surplus(+) (as % of GDP), Portugal  \
# 0                                             -2.918
# 1                                             -0.462
# 2                                              1.578
# 3                                              3.281
# 4                                                NaN
#
#    Government debt (consolidated) (as % of GDP), Portugal  \
# 0                                            134.096
# 1                                            123.878
# 2                                            111.232
# 3                                             97.930
# 4                                                NaN
#
#    Gross fixed capital formation, Portugal
# 0                                -2.341932
# 1                                 7.789368
# 2                                 3.336517
# 3                                 3.586178
# 4                                 2.305466
#
# [5 rows x 23 columns]

# %%
monthly_ecb_data = extract_and_combine_data(transformed_data, 'Monthly')
monthly_ecb_data['TIME_PERIOD'] = monthly_ecb_data['TIME_PERIOD'].dt.date
monthly_ecb_data
# Out:
#    TIME_PERIOD  Unemployment rate, Portugal
# 0   2020-01-01                     6.781716
# 1   2020-02-01                     6.489416
# 2   2020-03-01                     5.843906
# 3   2020-04-01                     5.756566
# 4   2020-05-01                     6.093323
# ..         ...                          ...
# 56  2024-09-01                     6.500207
# 57  2024-10-01                     6.560763
# 58  2024-11-01                     6.565637
# 59  2024-12-01                     6.373536
# 60  2025-01-01                     6.209970
#
# [61 rows x 2 columns]

# %% [markdown]
# ## Escrever o excel

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Alignment
from openpyxl.utils import get_column_letter

def write_df_to_sheet(sheet, df):
    for c_idx, col_name in enumerate(df.columns, 1):
        sheet.cell(row=1, column=c_idx, value=col_name)
    for r_idx, row in enumerate(df.values, 1):
        for c_idx, value in enumerate(row, 1):
            sheet.cell(row=r_idx + 1, column=c_idx, value=value)

yellow_fill = PatternFill(start_color="FFFF00", end_color="FFFF00", fill_type="solid")
white_font = Font(color="FFFFFF", bold=True)
green_fill = PatternFill(start_color=obi.nb_default_color1.split('#')[1], end_color=obi.nb_default_color1.split('#')[1], fill_type="solid")
pink_fill = PatternFill(start_color="FFCCE5", end_color="FFCCE5", fill_type="solid")
blue_fill = PatternFill(start_color="311CEE", end_color="311CEE", fill_type="solid")

wb = load_workbook("indicadores_bpstat_com_header.xlsx")

ws1 = wb.active
ws1.title = "BPSTAT_LDPs"

sheet = wb["BPSTAT_LDPs"]

sheet['A3'].fill = blue_fill
sheet['A3'].alignment = Alignment(horizontal="center", vertical="center")
sheet['A3'] = 'Date'
sheet['A3'].font = Font(color="FFFFFF", bold=True) 

for row in sheet.iter_rows(min_row=4, max_row=sheet.max_row, min_col=1, max_col=1):
    for cell in row:
        if isinstance(cell.value, pd.Timestamp):
            cell.value = cell.value.date()
        cell.fill = yellow_fill
        cell.font = Font(color="000000", bold=True) 
        cell.alignment = Alignment(horizontal="center", vertical="center")

for col in range(2, sheet.max_column + 1):
    for row in range(1, 3):
        cell = sheet.cell(row=row, column=col)
        if row == 1:
            cell.fill = pink_fill
            cell.font = Font(color="000000", bold=True)  
        elif row == 2:
            cell.fill = green_fill
            cell.font = Font(color="FFFFFF", bold=True) 
        cell.alignment = Alignment(horizontal="center", vertical="center")

for col in sheet.iter_cols(min_col=1, max_col=sheet.max_column):
    max_length = 0
    for cell in col:
        if cell.value:
            max_length = max(max_length, len(str(cell.value)))
    sheet.column_dimensions[get_column_letter(col[0].column)].width = max_length + 2

ws_quarterly = wb.create_sheet("Quarterly_ECB")
ws_monthly = wb.create_sheet("Monthly_ECB")
ws_annual = wb.create_sheet("Annual_ECB")
ws_readme = wb.create_sheet("README")


write_df_to_sheet(ws_quarterly, quarterly_ecb_data)
write_df_to_sheet(ws_monthly, monthly_ecb_data)
write_df_to_sheet(ws_annual, annual_ecb_data)

for sheet in [ws_quarterly, ws_monthly, ws_annual]:
    for row in sheet.iter_rows(min_row=2, max_row=sheet.max_row, min_col=1, max_col=1):
        for cell in row:
            if isinstance(cell.value, pd.Timestamp):
                cell.value = cell.value.date()
            cell.fill = yellow_fill
            cell.font = Font(color="000000", bold=True)
            cell.alignment = Alignment(horizontal="center", vertical="center")

    for col in range(1, sheet.max_column + 1):
        cell = sheet.cell(row=1, column=col)
        cell.fill = green_fill
        cell.font = Font(color="FFFFFF", bold=True)
        cell.alignment = Alignment(horizontal="center", vertical="center")

    for col in sheet.iter_cols(min_col=1, max_col=sheet.max_column):
        max_length = 0
        for cell in col:
            if cell.value:
                max_length = max(max_length, len(str(cell.value)))
        sheet.column_dimensions[get_column_letter(col[0].column)].width = max_length + 5

    sheet['A1'] = 'Date'
    sheet['A1'].alignment = Alignment(horizontal="center", vertical="center")
    sheet['A1'].font = Font(bold=True, color = "000000")
    sheet['A1'].fill = pink_fill

wb.save("output_final.xlsx")

# %% [markdown]
# # DADOS

# %%
display(
df_final.head(),
df_final_semh.head(),
quarterly_ecb_data.head(),
annual_ecb_data.head(),
monthly_ecb_data.head()
       )
# Out:
#         Date  Current ratio-C18 Printing  Current ratio-J58 Publishing  \
# 0 2006-12-31                      109.00                        130.65
# 1 2007-12-31                      112.31                        131.24
# 2 2008-12-31                      111.10                        124.05
# 3 2009-12-31                      112.33                        127.11
# 4 2010-12-31                      127.30                        122.00
#
#    Current ratio-H51 Air transport  Current ratio-G45 Trade motor vehicles  \
# 0                           171.56                                  114.21
# 1                           127.79                                  116.26
# 2                           125.44                                  110.88
# 3                           118.17                                  110.58
# 4                           151.35                                  115.62
#
#    Current ratio-F Construction  Current ratio-C20 Chemicals  \
# 0                        154.95                       130.67
# 1                        157.48                       131.69
# 2                        155.37                       121.80
# 3                        154.37                       113.76
# 4                        143.78                       123.69
#
#    Current ratio-C17 Paper  Current ratio-I56 Food service activities  \
# 0                   179.64                                      71.24
# 1                   169.40                                      71.26
# 2                   109.99                                      68.58
# 3                   103.88                                      69.29
# 4                   116.35                                      74.92
#
#    Current ratio-J63 Computer services  ...  \
# 0                               138.54  ...
# 1                               138.03  ...
# 2                               153.76  ...
# 3                               147.12  ...
# 4                               144.28  ...
#
#    Financial pressure-Automobile-Manufact motor vehic-%  \
# 0                                               8.49
# 1                                               8.40
# 2                                              12.78
# 3                                              14.74
# 4                                              10.63
#
#    Financial pressure-Maritime-Sea transport-%  \
# 0                                         8.46
# 1                                         9.60
# 2                                        12.92
# 3                                         7.69
# 4                                        10.31
#
#    Financial pressure-Food manufact-%  \
# 0                               14.03
# 1                               18.42
# 2                               23.11
# 3                               15.62
# 4                               17.34
#
#    Financial pressure-Info & communication-Telecommunic-%  \
# 0                                               6.61
# 1                                               7.15
# 2                                               8.71
# 3                                               7.24
# 4                                               2.35
#
#    Financial pressure-Footwear-%  Financial pressure-Transportation-%  \
# 0                          19.74                                26.74
# 1                          17.05                                26.25
# 2                          19.27                                39.93
# 3                          16.54                                29.68
# 4                          18.41                                22.03
#
#    Financial pressure-G Trade-%  Financial pressure-E Water and waste-%  \
# 0                         20.17                                   15.80
# 1                         20.47                                   18.42
# 2                         26.48                                   21.95
# 3                         22.08                                   18.53
# 4                         22.01                                   18.60
#
#    Financial pressure-Transportation-Water transport-%  \
# 0                                               6.67
# 1                                               8.41
# 2                                              15.00
# 3                                              12.32
# 4                                              23.16
#
#    Financial pressure-electricity, gas and water-%
# 0                                            15.97
# 1                                            25.29
# 2                                            29.61
# 3                                            25.36
# 4                                            23.89
#
# [5 rows x 230 columns]
#            Liquidez geral                                   \
#              C18 Printing J58 Publishing H51 Air transport
# 2006-12-31         109.00         130.65            171.56
# 2007-12-31         112.31         131.24            127.79
# 2008-12-31         111.10         124.05            125.44
# 2009-12-31         112.33         127.11            118.17
# 2010-12-31         127.30         122.00            151.35
#
#                                                                             \
#            G45 Trade motor vehicles F Construction C20 Chemicals C17 Paper
# 2006-12-31                   114.21         154.95        130.67    179.64
# 2007-12-31                   116.26         157.48        131.69    169.40
# 2008-12-31                   110.88         155.37        121.80    109.99
# 2009-12-31                   110.58         154.37        113.76    103.88
# 2010-12-31                   115.62         143.78        123.69    116.35
#
#                                                                                \
#            I56 Food service activities J63 Computer services G47 Retail trade
# 2006-12-31                       71.24                138.54           100.27
# 2007-12-31                       71.26                138.03            96.63
# 2008-12-31                       68.58                153.76            96.86
# 2009-12-31                       69.29                147.12            97.54
# 2010-12-31                       74.92                144.28           100.03
#
#             ... Pressão financeira (gastos de financiamento)           \
#             ...                                   Automobile Maritime
# 2006-12-31  ...                                         8.49     8.46
# 2007-12-31  ...                                         8.40     9.60
# 2008-12-31  ...                                        12.78    12.92
# 2009-12-31  ...                                        14.74     7.69
# 2010-12-31  ...                                        10.63    10.31
#
#                                                                                \
#            Food manufact Info & communication Footwear Transportation G Trade
# 2006-12-31         14.03                 6.61    19.74          26.74   20.17
# 2007-12-31         18.42                 7.15    17.05          26.25   20.47
# 2008-12-31         23.11                 8.71    19.27          39.93   26.48
# 2009-12-31         15.62                 7.24    16.54          29.68   22.08
# 2010-12-31         17.34                 2.35    18.41          22.03   22.01
#
#
#            E Water and waste Transportation electricity, gas and water
# 2006-12-31             15.80           6.67                      15.97
# 2007-12-31             18.42           8.41                      25.29
# 2008-12-31             21.95          15.00                      29.61
# 2009-12-31             18.53          12.32                      25.36
# 2010-12-31             18.60          23.16                      23.89
#
# [5 rows x 224 columns]
#   TIME_PERIOD  Private final consumption, Portugal  \
# 0  2020-01-01                            -1.008016
# 1  2020-04-01                           -16.552394
# 2  2020-07-01                            -4.256041
# 3  2020-10-01                            -5.242758
# 4  2021-01-01                            -7.222002
#
#    Gross fixed capital formation, Portugal  \
# 0                                -1.259336
# 1                                -8.579667
# 2                                -0.101212
# 3                                 0.570004
# 4                                 3.803724
#
#    Gross entrepreneurial income of Non financial corporations as a ratio of gross value added, Portugal  \
# 0                                          41.658218
# 1                                          40.736724
# 2                                          40.767762
# 3                                          40.073375
# 4                                          40.641991
#
#    Total financial assets of Non financial corporations (growth rate), Portugal  \
# 0                                           0.784481
# 1                                           1.864120
# 2                                           2.945065
# 3                                           3.916514
# 4                                           5.793014
#
#    Total financial liabilities of Non financial corporations (growth rate), Portugal  \
# 0                                           1.378025
# 1                                           2.037655
# 2                                           2.310132
# 3                                           2.775165
# 4                                           3.842996
#
#    Total financial assets of households (growth rate), Portugal  \
# 0                                           1.363584
# 1                                           2.464528
# 2                                           2.699639
# 3                                           2.953375
# 4                                           3.749417
#
#    Loans granted to households (growth rate), Portugal  \
# 0                                           1.269223
# 1                                           1.091716
# 2                                           1.518988
# 3                                           1.727187
# 4                                           2.179259
#
#    Total employment, Euro area 20 (fixed composition) as of 1 January 2023  \
# 0                                           0.483336
# 1                                          -2.743320
# 2                                          -1.968714
# 3                                          -1.471045
# 4                                          -1.291782
#
#    Labour Productivity (per persons), Portugal
# 0                                    -1.965161
# 1                                   -14.673158
# 2                                    -3.452963
# 3                                    -5.452797
# 4                                    -2.692835
#    TIME_PERIOD  Government final consumption, Portugal  \
# 0         2020                                0.398942
# 1         2021                                3.784391
# 2         2022                                1.656845
# 3         2023                                0.593048
# 4         2024                                1.053851
#
#    Imports of goods and services, Portugal  \
# 0                               -11.590377
# 1                                12.258844
# 2                                11.265565
# 3                                 1.796337
# 4                                 4.769482
#
#    Exports of goods and services, Portugal  \
# 0                               -18.334661
# 1                                12.034544
# 2                                17.152864
# 3                                 3.803727
# 4                                 3.418246
#
#    Gross domestic product at market prices, Portugal  \
# 0                                          -8.204631
# 1                                           5.558758
# 2                                           6.985840
# 3                                           2.613129
# 4                                           1.899942
#
#    Net value added of Non financial corporations (growth rate), Portugal  \
# 0                                         -11.474540
# 1                                           8.613068
# 2                                          16.692040
# 3                                          11.296385
# 4                                                NaN
#
#    Gross entrepreneurial income of Non financial corporations, Portugal  \
# 0                                          40.073375
# 1                                          42.351140
# 2                                          42.801191
# 3                                          41.402639
# 4                                                NaN
#
#    Debt securities and loans of Non financial corporations as a ratio of GDP, Portugal  \
# 0                                          92.290655
# 1                                          87.851286
# 2                                          78.589222
# 3                                          70.783122
# 4                                                NaN
#
#    Debt of Non financial corporations as a ratio of total financial liabilities, Portugal  \
# 0                                          40.811918
# 1                                          40.423061
# 2                                          38.947091
# 3                                          36.839599
# 4                                                NaN
#
#    Total financial assets of Non financial corporations as a ratio of total financial assets, Portugal  \
# 0                                           3.916514
# 1                                           3.778129
# 2                                           2.451700
# 3                                          -1.509845
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Gross saving of households as a ratio of adjusted gross disposable income, Portugal  \
# 0                                          12.047856
# 1                                          10.952782
# 2                                           7.329643
# 3                                           7.989961
# 4                                                NaN
#
#    Gross disposable income of households (growth rate), Portugal  \
# 0                                          -0.852711
# 1                                           5.629849
# 2                                           8.890484
# 3                                           7.221603
# 4                                                NaN
#
#    Total financial assets of households as a ratio of total financial assets, Portugal  \
# 0                                           2.953375
# 1                                           2.888199
# 2                                           1.733002
# 3                                           0.705166
# 4                                                NaN
#
#    Loans granted to households as a ratio of total financial assets, Portugal  \
# 0                                           1.727187
# 1                                           3.740656
# 2                                           3.249446
# 3                                           0.126336
# 4                                                NaN
#
#    Gross fixed capital formation of households as a ratio of adjusted gross disposable income, Portugal  \
# 0                                           5.449846
# 1                                           5.843595
# 2                                           5.917920
# 3                                           5.793576
# 4                                                NaN
#
#    Final consumption expenditure of households (growth rate), Portugal  \
# 0                                          -6.355738
# 1                                           7.037437
# 2                                          13.247677
# 3                                           6.432624
# 4                                                NaN
#
#    Government deficit(-) or surplus(+) (as % of GDP), Portugal  \
# 0                                             -5.752
# 1                                             -2.825
# 2                                             -0.310
# 3                                              1.214
# 4                                                NaN
#
#    Government primary deficit(-) or surplus(+) (as % of GDP), Portugal  \
# 0                                             -2.918
# 1                                             -0.462
# 2                                              1.578
# 3                                              3.281
# 4                                                NaN
#
#    Government debt (consolidated) (as % of GDP), Portugal  \
# 0                                            134.096
# 1                                            123.878
# 2                                            111.232
# 3                                             97.930
# 4                                                NaN
#
#    Gross fixed capital formation, Portugal
# 0                                -2.341932
# 1                                 7.789368
# 2                                 3.336517
# 3                                 3.586178
# 4                                 2.305466
#
# [5 rows x 23 columns]
#   TIME_PERIOD  Unemployment rate, Portugal
# 0  2020-01-01                     6.781716
# 1  2020-02-01                     6.489416
# 2  2020-03-01                     5.843906
# 3  2020-04-01                     5.756566
# 4  2020-05-01                     6.093323
